# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
x,y = make_regression(n_samples=10, n_features=3, n_informative=1, n_targets=1, noise=40, random_state=13)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x[:, 0], y)
plt.scatter(x[:, 1], y)
plt.scatter(x[:, 2], y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# np.float64(-2.4982044390238656)

# %%
reg.coef_
# Out:
# array([ 59.33683832,  21.77892842, -16.51347087])

# %%
plt.scatter(x[:, 0], y)
plt.scatter(x[:, 0], reg.predict(x))

# %%
reg.predict(x)
# Out:
# array([ 44.81503887,  49.14590012,  71.9557037 ,  21.13282432,
#        -16.4053615 ,  38.14312441, -27.61808968,  10.51092873,
#        -60.87742069, 106.859253  ])

# %%
y_pred = (59.33683832*x[:, 0] +  21.77892842*x[:, 1] + -16.51347087*x[:, 2] + 0)

# %%
y_pred
# Out:
# array([ 47.31324331,  51.64410456,  74.45390813,  23.63102877,
#        -13.90715707,  40.64132886, -25.11988524,  13.00913316,
#        -58.37921625, 109.35745745])

# %%
l = y_pred_l

# %%
bi = b 
sum = 0
y_pred_l = list()
for i in range(x.shape[1]):
    sum = sum + reg.coef_[i]*x[:, i]
    
y_pred_l = sum + bi

# %%
y_pred_l
# Out:
# array([ 43.55765141,  47.88851265,  70.69831623,  19.87543686,
#        -17.66274896,  36.88573695, -28.87547715,   9.25354126,
#        -62.13480816, 105.60186554])

# %%
lossSlop = -2*np.sum(y - y_pred_l)

# %%
lossSlop
# Out:
# np.float64(-25.147749291397417)

# %%
lr = 0.01
stepSize = lossSlop*lr 
stepSize
# Out:
# np.float64(-0.2514774929139742)

# %%
b = b - stepSize

# %%
y_pred = (59.33683832*x[:, 0] +  21.77892842*x[:, 1] + -16.51347087*x[:, 2] + b)

# %%
y_pred
# Out:
# array([ 43.8091289 ,  48.13999015,  70.94979372,  20.12691436,
#        -17.41127148,  37.13721445, -28.62399965,   9.50501875,
#        -61.88333066, 105.85334303])

# %%
reg.predict(x)
# Out:
# array([ 44.81503887,  49.14590012,  71.9557037 ,  21.13282432,
#        -16.4053615 ,  38.14312441, -27.61808968,  10.51092873,
#        -60.87742069, 106.859253  ])

# %%
l
# Out:
# array([ 43.24330454,  47.57416579,  70.38396937,  19.56108999,
#        -17.97709583,  36.57139008, -29.18982401,   8.9391944 ,
#        -62.44915502, 105.28751867])
